# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r'C:\Users\hahah\Desktop\tmdb_5000_credits.csv')
df2=pd.read_csv(r'C:\Users\hahah\Desktop\tmdb_5000_movies.csv')

# %%
df1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
df2.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df1.columns = ['id','tittle','cast','crew']
df2= df2.merge(df1,on='id')

# %%
df2.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
C= df2['vote_average'].mean()
C
# Out:
# 6.092171559442016

# %%
m= df2['vote_count'].quantile(0.9)
m
# Out:
# 1838.4000000000015

# %%
q_movies = df2.copy().loc[df2['vote_count'] >= m]
q_movies.shape
# Out:
# (481, 26)

# %%
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)

# %%
q=q_movies.sort_values('score', ascending=False)
q[['title', 'vote_count', 'vote_average', 'score']]
# Out:
#                              title  vote_count  vote_average     score
# 1881      The Shawshank Redemption        8205           8.5  8.059258
# 662                     Fight Club        9413           8.3  7.939256
# 65                 The Dark Knight       12002           8.2  7.920020
# 3232                  Pulp Fiction        8428           8.3  7.904645
# 96                       Inception       13752           8.1  7.863239
# ...                            ...         ...           ...       ...
# 41                   Green Lantern        2487           5.1  5.521697
# 337         A Good Day to Die Hard        3493           5.2  5.507643
# 193                    After Earth        2532           5.0  5.459420
# 91    Independence Day: Resurgence        2491           4.9  5.406234
# 242                 Fantastic Four        2278           4.4  5.155730
#
# [481 rows x 4 columns]

# %%
pop=df2.sort_values('popularity',ascending=False)
plt.barh(pop['title'].head(6),pop['popularity'].head(6), align='center',color='skyblue')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Language

# %%
df2.original_language.value_counts()
# Out:
# en    4505
# fr      70
# es      32
# de      27
# zh      27
# hi      19
# ja      16
# it      14
# cn      12
# ko      11
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# id       2
# ta       2
# cs       2
# ar       2
# ro       2
# te       1
# ky       1
# sl       1
# el       1
# xx       1
# hu       1
# vi       1
# no       1
# ps       1
# pl       1
# af       1
# is       1
# tr       1
# nb       1
# Name: original_language, dtype: int64

# %%
q_movies.original_language.value_counts()
# Out:
# en    473
# ja      3
# ko      2
# it      1
# es      1
# fr      1
# Name: original_language, dtype: int64

# %%
lg=q_movies.groupby(['original_language']).describe()
lg['vote_average'].sort_values('mean',ascending=False)
# Out:
#                    count      mean       std  min    25%   50%    75%  max
# original_language
# ja                   3.0  8.233333  0.057735  8.2  8.200  8.20  8.250  8.3
# it                   1.0  8.100000       NaN  8.1  8.100  8.10  8.100  8.1
# fr                   1.0  7.800000       NaN  7.8  7.800  7.80  7.800  7.8
# es                   1.0  7.600000       NaN  7.6  7.600  7.60  7.600  7.6
# ko                   2.0  7.350000  0.919239  6.7  7.025  7.35  7.675  8.0
# en                 473.0  6.947780  0.744671  4.4  6.400  7.00  7.500  8.5

# %%
lg['popularity'].sort_values('mean',ascending=False)
# Out:
#                    count       mean        std        min        25%  \
# original_language
# es                   1.0  90.809408        NaN  90.809408  90.809408
# it                   1.0  88.377076        NaN  88.377076  88.377076
# en                 473.0  79.056807  69.026220   1.859364  49.294864
# ja                   3.0  76.417095  37.272430  49.549984  55.141361
# fr                   1.0  73.720244        NaN  73.720244  73.720244
# ko                   2.0  60.501089   5.285763  56.763490  58.632290
#
#                          50%        75%         max
# original_language
# es                 90.809408  90.809408   90.809408
# it                 88.377076  88.377076   88.377076
# en                 65.677399  89.186492  875.581305
# ja                 60.732738  89.850650  118.968562
# fr                 73.720244  73.720244   73.720244
# ko                 60.501089  62.369889   64.238688

# %% [markdown]
# # Budget

# %%
bd=q_movies.sort_values(['budget'],ascending=False)
bd['title'].head(10)
# Out:
# 17    Pirates of the Caribbean: On Stranger Tides
# 1        Pirates of the Caribbean: At World's End
# 7                         Avengers: Age of Ultron
# 4                                     John Carter
# 6                                         Tangled
# 5                                    Spider-Man 3
# 13                                The Lone Ranger
# 8          Harry Potter and the Half-Blood Prince
# 98              The Hobbit: An Unexpected Journey
# 26                     Captain America: Civil War
# Name: title, dtype: object

# %%
bd['original_language'].head(1000).value_counts()
# Out:
# en    473
# ja      3
# ko      2
# it      1
# es      1
# fr      1
# Name: original_language, dtype: int64

# %%
bd[['title','vote_average']].head(10)
# Out:
#                                           title  vote_average
# 17  Pirates of the Caribbean: On Stranger Tides           6.4
# 1      Pirates of the Caribbean: At World's End           6.9
# 7                       Avengers: Age of Ultron           7.3
# 4                                   John Carter           6.1
# 6                                       Tangled           7.4
# 5                                  Spider-Man 3           5.9
# 13                              The Lone Ranger           5.9
# 8        Harry Potter and the Half-Blood Prince           7.4
# 98            The Hobbit: An Unexpected Journey           7.0
# 26                   Captain America: Civil War           7.1

# %%
bd[['title','vote_average']].tail(10)
# Out:
#                                 title  vote_average
# 3895                        The Purge           6.0
# 3940                           Oldboy           8.0
# 4259  Snow White and the Seven Dwarfs           6.9
# 4337                      Taxi Driver           8.0
# 4291                              Saw           7.2
# 4300                   Reservoir Dogs           8.0
# 4302   The Good, the Bad and the Ugly           8.1
# 2170                           Psycho           8.2
# 4602                     12 Angry Men           8.2
# 2862                       About Time           7.8

# %%
bd[['title','popularity']].head(10)
# Out:
#                                           title  popularity
# 17  Pirates of the Caribbean: On Stranger Tides  135.413856
# 1      Pirates of the Caribbean: At World's End  139.082615
# 7                       Avengers: Age of Ultron  134.279229
# 4                                   John Carter   43.926995
# 6                                       Tangled   48.681969
# 5                                  Spider-Man 3  115.699814
# 13                              The Lone Ranger   49.046956
# 8        Harry Potter and the Half-Blood Prince   98.885637
# 98            The Hobbit: An Unexpected Journey  108.849621
# 26                   Captain America: Civil War  198.372395

# %%
bd[['title','popularity']].tail(10)
# Out:
#                                 title  popularity
# 3895                        The Purge   54.403033
# 3940                           Oldboy   56.763490
# 4259  Snow White and the Seven Dwarfs   80.171283
# 4337                      Taxi Driver   58.845025
# 4291                              Saw   63.655973
# 4300                   Reservoir Dogs   66.925866
# 4302   The Good, the Bad and the Ugly   88.377076
# 2170                           Psycho   93.067866
# 4602                     12 Angry Men   59.259204
# 2862                       About Time   74.817641

# %% [markdown]
# # Companies

# %%
df2.production_companies.value_counts()
# Out:
# []                                                                                                                                                                                                                                                                              351
# [{"name": "Paramount Pictures", "id": 4}]                                                                                                                                                                                                                                        58
# [{"name": "Universal Pictures", "id": 33}]                                                                                                                                                                                                                                       45
# ...

# %%
q_movies.production_companies.value_counts()
# Out:
# [{"name": "Walt Disney Pictures", "id": 2}, {"name": "Pixar Animation Studios", "id": 3}]                                                                                                                                                                                                                                      10
# [{"name": "Marvel Studios", "id": 420}]                                                                                                                                                                                                                                                                                         8
# [{"name": "DreamWorks Animation", "id": 521}]                                                                                                                                                                                                                                                                                   6
# ...

# %%
q_movies.production_companies[0]
# Out:
# '[{"name": "Ingenious Film Partners", "id": 289}, {"name": "Twentieth Century Fox Film Corporation", "id": 306}, {"name": "Dune Entertainment", "id": 444}, {"name": "Lightstorm Entertainment", "id": 574}]'
